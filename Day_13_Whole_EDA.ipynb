# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Understand Data

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# #### Shapes & Data types

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### 2. Data Cleaning

# %%
tips.isnull()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
tips.drop_duplicates()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Numerical Columns

# %%
sns.histplot(tips['total_bill'])
plt.title('Distribution of Total Bill')
# Out:
# Text(0.5, 1.0, 'Distribution of Total Bill')

# %%
sns.histplot(tips['tip'])
plt.title('Distribution of Tips')
# Out:
# Text(0.5, 1.0, 'Distribution of Tips')

# %%
sns.histplot(tips['size'])
plt.title('Distribution of Size')
# Out:
# Text(0.5, 1.0, 'Distribution of Size')

# %%
plt.boxplot(x=tips['tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14ff08e30>,
#   <matplotlib.lines.Line2D at 0x14ff09160>],
#  'caps': [<matplotlib.lines.Line2D at 0x14ff09460>,
#   <matplotlib.lines.Line2D at 0x14ff096d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x14fe76600>],
#  'medians': [<matplotlib.lines.Line2D at 0x14ff09970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14ff09b80>],
#  'means': []}

# %%
sns.boxplot(x=tips['tip'])
plt.title('Boxplot of Tip Amount')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tip Amount')

# %% [markdown]
# ### Categorical Columns/Features

# %%
sns.countplot(x='day', data=tips)
plt.title('Count observation per day')
# Out:
# Text(0.5, 1.0, 'Count observation per day')

# %%
sns.countplot(x='sex', data=tips)
plt.title('Count observation per day')
# Out:
# Text(0.5, 1.0, 'Count observation per day')

# %%
sns.countplot(x='smoker', data=tips)
plt.title('Count observation of Smoker')
# Out:
# Text(0.5, 1.0, 'Count observation of Smoker')

# %%
sns.countplot(x='time', data=tips)
plt.title('Count observation of Timings')
# Out:
# Text(0.5, 1.0, 'Count observation of Timings')

# %%
sns.boxplot(x=tips['size'])
plt.title('Boxplot of Tip Amount')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tip Amount')

# %%
sns.boxplot(x=tips['total_bill'])
plt.title('Boxplot of Tip Amount')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tip Amount')

# %%
ab = np.array([18,19,17,17])

# %%
ab.mean()
# Out:
# 17.75

# %%
ac = np.array([18,19,17,17,180])

# %%
ab.mean()
# Out:
# 17.75

# %% [markdown]
# ### 4. Bivariate Analysis

# %% [markdown]
# #### Numerical-Numerical Relationship

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips, hue = 'tip', palette='coolwarm')
plt.title('Total Bill vs Tip')
plt.show()

# %%
sns.scatterplot(x='size',y='tip',data=tips, hue = 'tip', palette='coolwarm')
plt.title('Size vs Tip')
plt.show()

# %%
sns.scatterplot(x='total_bill',y='size',data=tips, hue = 'size', palette='coolwarm')
plt.title('Size vs Total Bill')
plt.show()

# %%
cor=tips.corr(numeric_only=True)

# %%
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.title('Coorelation between Numerical Values')
# Out:
# Text(0.5, 1.0, 'Coorelation between Numerical Values')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# #### Numerical - Categorical Relationship

# %%
sns.boxplot(x='sex',y='tip',data=tips)
plt.title('Tip amount by Gender/Sex')
# Out:
# Text(0.5, 1.0, 'Tip amount by Gender/Sex')

# %%
sns.boxplot(x='smoker',y='tip',data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.violinplot(x='smoker',y='tip',data=tips)
plt.title('Tip amount by Smoking habit')
# Out:
# Text(0.5, 1.0, 'Tip amount by Smoking habit')

# %% [markdown]
# #### Categorical - Categorical

# %%
sns.countplot(x='day',hue='time',data=tips)
plt.title('Day vs Time')
# Out:
# Text(0.5, 1.0, 'Day vs Time')

# %% [markdown]
# ### 6. Multivariate analysis

# %%
sns.pairplot(tips)
plt.title('Relationship and Distribution of Numerical Variables')
# Out:
# Text(0.5, 1.0, 'Relationship and Distribution of Numerical Variables')

# %%
sns.pairplot(tips, hue='sex')
plt.title('Relationship and Distribution of Numerical Variables')
# Out:
# Text(0.5, 1.0, 'Relationship and Distribution of Numerical Variables')

# %% [markdown]
# ### 6. Grouping and Aggregation

# %%
tips.groupby('sex')['tip'].mean()
# Out:
# /var/folders/b4/s91v63_j63vc83v40y45swt80000gn/T/ipykernel_2855/2929813174.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['tip'].mean()
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
tips.groupby('day').agg({'total_bill':'mean','tip':'mean'})
# Out:
# /var/folders/b4/s91v63_j63vc83v40y45swt80000gn/T/ipykernel_2855/3775092670.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('day').agg({'total_bill':'mean','tip':'mean'})
#       total_bill       tip
# day
# Thur   17.682742  2.771452
# Fri    17.151579  2.734737
# Sat    20.441379  2.993103
# Sun    21.410000  3.255132

# %%
tips.groupby(['sex','day'])['tip'].mean()
# Out:
# /var/folders/b4/s91v63_j63vc83v40y45swt80000gn/T/ipykernel_2855/1596412272.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex','day'])['tip'].mean()
# sex     day
# Male    Thur    2.980333
#         Fri     2.693000
#         Sat     3.083898
#         Sun     3.220345
# Female  Thur    2.575625
#         Fri     2.781111
#         Sat     2.801786
#         Sun     3.367222
# Name: tip, dtype: float64

# %% [markdown]
# ### 7. Feature Engineering

# %%
tips['tip_percent']=(tips['tip']/tips['total_bill'])*100
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2     5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3    16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3    16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2    13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4    14.680765

# %%
sns.histplot(tips['tip_percent'],kde = True)
plt.title('Distribution of Tip Percent')
# Out:
# Text(0.5, 1.0, 'Distribution of Tip Percent')

# %% [markdown]
# ### 8. Handling Outliers (or removing outlier)

# %%
tips['tip_percent'].describe()
# Out:
# count    244.000000
# mean      16.080258
# std        6.107220
# min        3.563814
# 25%       12.912736
# 50%       15.476977
# 75%       19.147549
# max       71.034483
# Name: tip_percent, dtype: float64

# %% [markdown]
# #### Using Domain Knowledge

# %%
tips_adjusted=tips[tips['tip_percent']<40]

# %%
tips_adjusted.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2     5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3    16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3    16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2    13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4    14.680765

# %%
tips_adjusted['tip_percent'].describe()
# Out:
# count    242.000000
# mean      15.747446
# std        4.716886
# min        3.563814
# 25%       12.853825
# 50%       15.408357
# 75%       18.995586
# max       32.573290
# Name: tip_percent, dtype: float64

# %% [markdown]
# ### Using the interquartile range

# %%
Q1 = tips['total_bill'].quantile(0.25)
Q3 = tips['total_bill'].quantile(0.75)

# %%
Q1
# Out:
# 13.3475

# %%
Q3
# Out:
# 24.127499999999998

# %% [markdown]
# #### Calculating IQR (Inter Quartile Range)

# %%
IQR = Q3 - Q1

# %%
IQR
# Out:
# 10.779999999999998

# %% [markdown]
# #### Boundaries Defining

# %%
#1.5 is standard threshold value
lower_bound=Q1-1.5*IQR 
upper_bound=Q3+1.5*IQR

# %%
lower_bound
# Out:
# -2.8224999999999945

# %%
upper_bound
# Out:
# 40.29749999999999

# %%
tips_clean=tips[(tips['total_bill']>=lower_bound) & (tips['total_bill']<=upper_bound)]

# %%
tips_clean['total_bill'].describe()
# Out:
# count    235.000000
# mean      18.798681
# std        7.438468
# min        3.070000
# 25%       13.215000
# 50%       17.460000
# 75%       23.135000
# max       40.170000
# Name: total_bill, dtype: float64
