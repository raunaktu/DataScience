# %%
import pandas as pd

#Load titanic dataset
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# Or if you have local file in desktop, use below
# path = r'C:\Users\user\OneDrive\Desktop\practice_timeseries.xlsx'
# df=pd.read_excel(path)

# %%
#view first few rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # Data Understanding

# %%
#Able to get how many rows and column are there in data frame datatype
#helps to check the no of rows and columns in the data
df.shape
# Out:
# (891, 12)

# %%
#check the data types and entries descriptions
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#In pandas, non numeric values are object

# %%
#Provide statistics
#provide stat of numeric data
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# given either the value in the respective column is null or not
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# Gives us the sum of no of null values in each column
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().head()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# 3  False  False     False
# 4  False   True     False

# %%
# Columns name of the dataframe
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#unique values in each columns
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# counts the values of each unique count
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
#Display random data
# Generates us the specific number of data samples randomly from the Dataframe
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 486          487         1       1
# 30            31         0       1
# 785          786         0       3
# 246          247         0       3
# 782          783         0       1
# 252          253         0       1
# 245          246         0       1
# 129          130         0       3
# 102          103         0       1
# 763          764         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 486  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.0      1
# 30                          Uruchurtu, Don. Manuel E    male  40.0      0
# 785               Harmer, Mr. Abraham (David Lishin)    male  25.0      0
# 246            Lindahl, Miss. Agda Thorilda Viktoria  female  25.0      0
# 782                           Long, Mr. Milton Clyde    male  29.0      0
# 252                        Stead, Mr. William Thomas    male  62.0      0
# ...

# %%
#Show duplicated rows in Data Frame
df.duplicated().sum()
# Out:
# 0

# %%
#Sort data frame by age in desc order for top 20 rows
df.sort_values(by='Age',ascending=False).head(20)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                        Svensson, Mr. Johan
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 280          281         0       3                           Duane, Mr. Frank
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
#Sort data frame by age in ascending order for top 20 rows
df.sort_values(by='Age').head(10)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 831          832         1       2  Richards, Master. George Sibley    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 827          828         1       2            Mallet, Master. Andre    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 164          165         0       3     Panula, Master. Eino Viljami    male
#
#       Age  SibSp  Parch           Ticket      Fare    Cabin Embarked
# ...

# %%
#helps to find the index of the data frame
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# inplace attribute replaces original index of data frame
# changed index from default to PassengerID
df.set_index('PassengerId',inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
#check data types of the columns
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
# Check the aggregate insight of Survived grouping by Sex
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Check the aggregate insight of Age grouping by PClass
df.groupby('Pclass')['Ticket'].min()
# Out:
# Pclass
# 1    110152
# 2     11668
# 3     12460
# Name: Ticket, dtype: object

# %%
# Check the aggregate insight of Age grouping by PClass
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
df.Fare.head()
# Out:
# PassengerId
# 1     7.2500
# 2    71.2833
# 3     7.9250
# 4    53.1000
# 5     8.0500
# Name: Fare, dtype: float64

# %%
#apply function to change the currency from pound to nrs
df['Fare']=df['Fare'].apply(lambda x : x*178)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket        Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   1290.5000   NaN        S
# 2                1      0          PC 17599  12688.4274   C85        C
# ...

# %%
df['Embarked'].replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'})
# Out:
# PassengerId
# 1      Southampton
# 2        Cherbourg
# 3      Southampton
# 4      Southampton
# 5      Southampton
#           ...
# 887    Southampton
# 888    Southampton
# 889    Southampton
# 890      Cherbourg
# 891     Queenstown
# Name: Embarked, Length: 891, dtype: object

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket        Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   1290.5000   NaN        S
# 2                1      0          PC 17599  12688.4274   C85        C
# ...

# %%
#inplace will completely override data
#replacing full name of letters in embarked column
df['Embarked'].replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'}, inplace = True)
# Out:
# /var/folders/b4/s91v63_j63vc83v40y45swt80000gn/T/ipykernel_5167/546922264.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'}, inplace = True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket        Fare Cabin     Embarked
# PassengerId
# 1                1      0         A/5 21171   1290.5000   NaN  Southampton
# 2                1      0          PC 17599  12688.4274   C85    Cherbourg
# ...

# %%
#Renaming the column SibSP and Parch
df.rename(columns = {'SibSp':'Sibling_Spouse','Parch':'Parents_Child'}, inplace  = True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket        Fare  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
#Renaming the column Fare and Embarked
df.rename(columns = {'Fare':'Fare_Npr','Embarked':'Port'}, inplace  = True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket    Fare_Npr  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
#Reset the index to default
df.reset_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket    Fare_Npr  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
df_1 = df[['Survived', 'Pclass', 'Age', 'Fare_Npr']]

# %%
df_1
# Out:
#              Survived  Pclass   Age    Fare_Npr
# PassengerId
# 1                   0       3  22.0   1290.5000
# 2                   1       1  38.0  12688.4274
# 3                   1       3  26.0   1410.6500
# 4                   1       1  35.0   9451.8000
# 5                   0       3  35.0   1432.9000
# ...               ...     ...   ...         ...
# 887                 0       2  27.0   2314.0000
# 888                 1       1  19.0   5340.0000
# 889                 0       3   NaN   4174.1000
# 890                 1       1  26.0   5340.0000
# 891                 0       3  32.0   1379.5000
#
# [891 rows x 4 columns]

# %%
df_1.corr()
# Out:
#           Survived    Pclass       Age  Fare_Npr
# Survived  1.000000 -0.338481 -0.077221  0.257307
# Pclass   -0.338481  1.000000 -0.369226 -0.549500
# Age      -0.077221 -0.369226  1.000000  0.096067
# Fare_Npr  0.257307 -0.549500  0.096067  1.000000

# %%
df_1.quantile(0.25)
# Out:
# Survived       0.0000
# Pclass         2.0000
# Age           20.1250
# Fare_Npr    1408.0512
# Name: 0.25, dtype: float64

# %%
#Calculate the quantile of numerical column
df_1.quantile(0.75)
# Out:
# Survived       1.0
# Pclass         3.0
# Age           38.0
# Fare_Npr    5518.0
# Name: 0.75, dtype: float64

# %%
#check the unique categories in port column
df['Port'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df_2 = df['Age'].where(df['Age']>20)

# %%
df_2.sample(20)
# Out:
# PassengerId
# 455     NaN
# 219    32.0
# 871    26.0
# 620    26.0
# 390     NaN
# 67     29.0
# 625    21.0
# 29      NaN
# 187     NaN
# 551     NaN
# 805    27.0
# 264    40.0
# 339    45.0
# 796    39.0
# 807    39.0
# 268    25.0
# 848    35.0
# 420     NaN
# 854     NaN
# 684     NaN
# Name: Age, dtype: float64

# %% [markdown]
# # NUMPY

# %%
import numpy as np

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket    Fare_Npr  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
#check data types of the columns
df.dtypes
# Out:
# Survived            int64
# Pclass              int64
# Name               object
# Sex                object
# Age               float64
# Sibling_Spouse      int64
# Parents_Child       int64
# Ticket             object
# Fare_Npr          float64
# Cabin              object
# Port               object
# dtype: object

# %%
age=np.array(df['Age'])

# %%
age
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
np.isnan(age)
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False,  True, False, False, False, False, False, False,  True,
#        False,  True,  True, False,  True,  True, False, False, False,
#         True, False, False, False, False, False,  True, False, False,
#         True,  True,  True,  True, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False, False, False,  True,  True, False, False, False,
#        False,  True, False, False, False, False,  True, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False,  True, False, False, False, False, False,  True,
#        False,  True, False, False, False, False, False, False, False,
# ...

# %%
np.isnan(age).sum()
# Out:
# 177

# %%
np.mean(df['Fare_Npr'])
# Out:
# 5732.349018406285

# %%
np.median(df['Fare_Npr'])
# Out:
# 2572.8476

# %%
np.std(df['Fare_Npr'])
# Out:
# 8840.465131169785

# %% [markdown]
# # Important

# %%
#Creating new features
df['Age_Category']=np.where(df['Age']>18,'Adult','Child')

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket    Fare_Npr  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
df.Age_Category.value_counts()
# Out:
# Age_Category
# Adult    575
# Child    316
# Name: count, dtype: int64

# %%
# Handling missing value with numpy
df['Age']=df['Age'].fillna(np.mean(df['Age']))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Pclass          891 non-null    int64
#  2   Name            891 non-null    object
#  3   Sex             891 non-null    object
#  4   Age             891 non-null    float64
#  5   Sibling_Spouse  891 non-null    int64
#  6   Parents_Child   891 non-null    int64
#  7   Ticket          891 non-null    object
#  8   Fare_Npr        891 non-null    float64
#  9   Cabin           204 non-null    object
#  10  Port            889 non-null    object
#  11  Age_Category    891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 90.5+ KB

# %%
# Advanced Grouping and Aggregation
df_grouped=df.groupby('Pclass').agg({
    'Age':['mean','median'],
    'Fare_Npr':['mean','median']
})

# %%
df_grouped
# Out:
#               Age                 Fare_Npr
#              mean     median          mean     median
# Pclass
# 1       37.048118  35.000000  14979.534375  10731.175
# 2       29.866958  29.699118   3677.868601   2536.500
# 3       26.403259  29.699118   2434.247918   1432.900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Pclass          891 non-null    int64
#  2   Name            891 non-null    object
#  3   Sex             891 non-null    object
#  4   Age             891 non-null    float64
#  5   Sibling_Spouse  891 non-null    int64
#  6   Parents_Child   891 non-null    int64
#  7   Ticket          891 non-null    object
#  8   Fare_Npr        891 non-null    float64
#  9   Cabin           204 non-null    object
#  10  Port            889 non-null    object
#  11  Age_Category    891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 90.5+ KB

# %%
#This will drop column

df=df.drop('Cabin',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Pclass          891 non-null    int64
#  2   Name            891 non-null    object
#  3   Sex             891 non-null    object
#  4   Age             891 non-null    float64
#  5   Sibling_Spouse  891 non-null    int64
#  6   Parents_Child   891 non-null    int64
#  7   Ticket          891 non-null    object
#  8   Fare_Npr        891 non-null    float64
#  9   Port            889 non-null    object
#  10  Age_Category    891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        889 non-null    int64
#  1   Pclass          889 non-null    int64
#  2   Name            889 non-null    object
#  3   Sex             889 non-null    object
#  4   Age             889 non-null    float64
#  5   Sibling_Spouse  889 non-null    int64
#  6   Parents_Child   889 non-null    int64
#  7   Ticket          889 non-null    object
#  8   Fare_Npr        889 non-null    float64
#  9   Port            889 non-null    object
#  10  Age_Category    889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.3+ KB

# %%
df.to_csv('data/titanic.csv', index = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        889 non-null    int64
#  1   Pclass          889 non-null    int64
#  2   Name            889 non-null    object
#  3   Sex             889 non-null    object
#  4   Age             889 non-null    float64
#  5   Sibling_Spouse  889 non-null    int64
#  6   Parents_Child   889 non-null    int64
#  7   Ticket          889 non-null    object
#  8   Fare_Npr        889 non-null    float64
#  9   Port            889 non-null    object
#  10  Age_Category    889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.3+ KB
