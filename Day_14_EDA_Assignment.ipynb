# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
fitness = sns.load_dataset('exercise')
fitness.tail(10)
# Out:
#     Unnamed: 0  id    diet  pulse    time     kind
# 80          80  27  no fat    140  30 min  running
# 81          81  28  no fat    103   1 min  running
# 82          82  28  no fat    124  15 min  running
# 83          83  28  no fat    140  30 min  running
# 84          84  29  no fat     94   1 min  running
# 85          85  29  no fat    135  15 min  running
# 86          86  29  no fat    130  30 min  running
# 87          87  30  no fat     99   1 min  running
# 88          88  30  no fat    111  15 min  running
# 89          89  30  no fat    150  30 min  running

# %%
fitness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  90 non-null     int64
#  1   id          90 non-null     int64
#  2   diet        90 non-null     category
#  3   pulse       90 non-null     int64
#  4   time        90 non-null     category
#  5   kind        90 non-null     category
# dtypes: category(3), int64(3)
# memory usage: 2.9 KB

# %%
fitness.shape
# Out:
# (90, 6)

# %%
fitness.describe()
# Out:
#        Unnamed: 0         id       pulse
# count   90.000000  90.000000   90.000000
# mean    44.500000  15.500000   99.700000
# std     26.124701   8.703932   14.858471
# min      0.000000   1.000000   80.000000
# 25%     22.250000   8.000000   90.250000
# 50%     44.500000  15.500000   96.000000
# 75%     66.750000  23.000000  103.000000
# max     89.000000  30.000000  150.000000

# %%
fitness.isnull().sum()
# Out:
# Unnamed: 0    0
# id            0
# diet          0
# pulse         0
# time          0
# kind          0
# dtype: int64

# %%
fitness.drop_duplicates()
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.countplot(x=fitness['id']==1, data=fitness, hue='time')
# Out:
# <Axes: xlabel='id', ylabel='count'>

# %% [markdown]
# ## Univariate Analysis

# %%
sns.histplot(x=fitness['id'])
plt.title("id distribution")
# Out:
# Text(0.5, 1.0, 'id distribution')

# %%
sns.boxplot(x=fitness['id'])
plt.title("id distribution")
# Out:
# Text(0.5, 1.0, 'id distribution')

# %%
sns.histplot(x=fitness['diet'])
plt.title("Diet distribution")
# Out:
# Text(0.5, 1.0, 'Diet distribution')

# %%
sns.boxplot(x=fitness['diet'])
plt.title("Diet distribution")
# Out:
# Text(0.5, 1.0, 'Diet distribution')

# %%
sns.histplot(x=fitness['pulse'])
plt.title('Distribution of pulse')
# Out:
# Text(0.5, 1.0, 'Distribution of pulse')

# %%
sns.boxplot(x=fitness['pulse'])
plt.title('Distribution of pulse')
# Out:
# Text(0.5, 1.0, 'Distribution of pulse')

# %%
sns.histplot(x=fitness['time'])
plt.title('Distribution of time')
# Out:
# Text(0.5, 1.0, 'Distribution of time')

# %%
sns.boxplot(x=fitness['time'])
plt.title('Distribution of time')
# Out:
# Text(0.5, 1.0, 'Distribution of time')

# %%
sns.histplot(x=fitness['kind'])
plt.title('Distribution of kind')
# Out:
# Text(0.5, 1.0, 'Distribution of kind')

# %%
sns.boxplot(x=fitness['kind'])
plt.title('Distribution of kind')
# Out:
# Text(0.5, 1.0, 'Distribution of kind')

# %% [markdown]
# #### Categorical Column / Features

# %%
sns.countplot(x='kind', data=fitness)
plt.title('Count observation per kind')
# Out:
# Text(0.5, 1.0, 'Count observation per kind')

# %% [markdown]
# ## Bivariate Analysis

# %%
fitness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  90 non-null     int64
#  1   id          90 non-null     int64
#  2   diet        90 non-null     category
#  3   pulse       90 non-null     int64
#  4   time        90 non-null     category
#  5   kind        90 non-null     category
# dtypes: category(3), int64(3)
# memory usage: 2.9 KB

# %% [markdown]
# ### Coorelation

# %%
cor=fitness.corr(numeric_only=True)
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.title('Coorelation between Numerical Values')
# Out:
# Text(0.5, 1.0, 'Coorelation between Numerical Values')

# %%
sns.scatterplot(x='Unnamed: 0',y='pulse',data=fitness, hue = 'pulse', palette='coolwarm')
plt.title('diet vs pulse')
plt.show()

# %%
sns.scatterplot(x='id',y='pulse',data=fitness, hue = 'pulse', palette='coolwarm')
plt.title('diet vs pulse')
plt.show()

# %%
sns.scatterplot(x='diet',y='pulse',data=fitness, hue = 'id', palette='coolwarm')
plt.title('diet vs pulse')
plt.show()

# %%
sns.scatterplot(x='diet',y='time',data=fitness, hue = 'time', palette='coolwarm')
plt.title('diet vs time')
plt.show()

# %%
sns.scatterplot(x='diet',y='kind',data=fitness, hue = 'kind', palette='coolwarm')
plt.title('diet vs kind')
plt.show()

# %%
sns.scatterplot(x='pulse',y='time',data=fitness, hue = 'time', palette='coolwarm')
plt.title('pulse vs time')
plt.show()

# %%
sns.scatterplot(x='pulse',y='kind',data=fitness, hue = 'kind', palette='coolwarm')
plt.title('pulse vs kind')
plt.show()

# %%
sns.scatterplot(x='time',y='kind',data=fitness, hue = 'kind', palette='coolwarm')
plt.title('time vs kind')
plt.show()

# %% [markdown]
# ### Numerical - Categorical

# %%
fitness.columns
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
sns.boxplot(x='id',y='pulse',data=fitness)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
sns.boxplot(x='diet',y='pulse',data=fitness)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
sns.boxplot(x='time',y='pulse',data=fitness)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
sns.boxplot(x='kind',y='pulse',data=fitness)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
sns.boxplot(x='Unnamed: 0',y='pulse',data=fitness)
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %% [markdown]
# ### Categorical - Categorical

# %%
fitness.columns
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
sns.countplot(x='id',hue='diet',data=fitness)
# Out:
# <Axes: xlabel='id', ylabel='count'>

# %%
sns.countplot(x='id',hue='time',data=fitness)
# Out:
# <Axes: xlabel='id', ylabel='count'>

# %%
sns.countplot(x='id',hue='kind',data=fitness)
# Out:
# <Axes: xlabel='id', ylabel='count'>

# %%
sns.countplot(x='diet',hue='id',data=fitness)
# Out:
# <Axes: xlabel='diet', ylabel='count'>

# %%
sns.countplot(x='diet',hue='kind',data=fitness)
# Out:
# <Axes: xlabel='diet', ylabel='count'>

# %%
sns.countplot(x='kind',hue='time',data=fitness)
# Out:
# <Axes: xlabel='kind', ylabel='count'>

# %% [markdown]
# ### Multivariate analysis

# %%
sns.pairplot(fitness)
plt.title('Relationship and Distribution of Numerical Variables')
# Out:
# Text(0.5, 1.0, 'Relationship and Distribution of Numerical Variables')

# %%
fitness.columns
# Out:
# Index(['Unnamed: 0', 'id', 'diet', 'pulse', 'time', 'kind'], dtype='object')

# %%
fitness.groupby(['id','diet','pulse']).count()
# Out:
# /var/folders/b4/s91v63_j63vc83v40y45swt80000gn/T/ipykernel_11052/2194987528.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fitness.groupby(['id','diet','pulse']).count()
#                   Unnamed: 0  time  kind
# id diet    pulse
# 1  no fat  80              0     0     0
#            82              0     0     0
#            83              0     0     0
#            84              0     0     0
#            85              0     0     0
# ...                      ...   ...   ...
# 30 low fat 132             0     0     0
#            135             0     0     0
#            140             0     0     0
#            143             0     0     0
#            150             0     0     0
#
# [2340 rows x 3 columns]
